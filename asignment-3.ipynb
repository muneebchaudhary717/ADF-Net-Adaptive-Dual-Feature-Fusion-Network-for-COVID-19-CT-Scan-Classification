# %%
# !git clone https://github.com/muneebchaudhary717/ADF-Net-Adaptive-Dual-Feature-Fusion-Network-for-COVID-19-CT-Scan-Classification.git
# Out:
# Cloning into 'ADF-Net-Adaptive-Dual-Feature-Fusion-Network-for-COVID-19-CT-Scan-Classification'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 25 (delta 5), reused 24 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 14.84 KiB | 4.95 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd ADF-Net-Adaptive-Dual-Feature-Fusion-Network-for-COVID-19-CT-Scan-Classification
# Out:
# /kaggle/working/ADF-Net-Adaptive-Dual-Feature-Fusion-Network-for-COVID-19-CT-Scan-Classification

# %%
# !pip install -r requirements.txt

# %%
# Git pull se update karein:
# !git pull origin main
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 569 bytes | 569.00 KiB/s, done.
# From https://github.com/muneebchaudhary717/ADF-Net-Adaptive-Dual-Feature-Fusion-Network-for-COVID-19-CT-Scan-Classification
#  * branch            main       -> FETCH_HEAD
#    e12c7c5..b5cc62e  main       -> origin/main
# Updating e12c7c5..b5cc62e
# Fast-forward
#  evaluate.py | 7 ++++++-
#  predict.py  | 7 ++++++-
#  2 files changed, 12 insertions(+), 2 deletions(-)

# %%
# !git pull origin
# Out:
# Already up to date.

# %%
# !python train.py --dataset_dir "/kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset" --epochs 30 --batch_size 32
# Out:
# Loading data from:
#  - Train: /kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset/train
#  - Val: /kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset/validation
#  - Test: /kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset/test
# [Fallback] Train directory not found. Loading dynamically from flat directory: /kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset
# Loading 1252 images for class 'COVID'...
# Loading 1229 images for class 'non-COVID'...
# Dynamic dataset split: Train=1736, Val=372, Test=373
# Detected Classes: ['COVID', 'non-COVID'] (Total: 2)
# Building ADF-Net model architecture...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785286881.241581     525 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# ...

# %%
# !python evaluate.py --dataset_dir "/kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset" --model_path "best_model.h5" --plots_dir "results"
# Out:
# Loading test generator...
# [Fallback] Train directory not found. Loading dynamically from flat directory: /kaggle/input/datasets/plameneduardo/sarscov2-ctscan-dataset
# Loading 1252 images for class 'COVID'...
# Loading 1229 images for class 'non-COVID'...
# Dynamic dataset split: Train=1736, Val=372, Test=373
# Loading trained ADF-Net model from: best_model.h5...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785287329.156916     846 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1785287329.162393     846 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# ...

# %%
import glob
from IPython.display import Image, display

# Results folder ke andar saved graphs ko show karne ke liye
images = glob.glob('results/*.png')
for img_path in sorted(images):
    print(f"Displaying: {img_path}")
    display(Image(filename=img_path))
# Out:
# Displaying: results/confusion_matrix.png
# Displaying: results/precision_recall_curve.png
# Displaying: results/roc_curve.png
# Displaying: results/training_accuracy.png
# Displaying: results/training_loss.png
